# %% [markdown]
# ### Getting Data for My Final Project

# %% [markdown]
# I want to use the data from the 2023_pageviews to get the
# - articles titles
# - qid
# - lang_code
# - country_code
# - pageviews

# %% [markdown]
# So far, I am a little confused about where I should be working on this project and how to use the duckdb databases

# %% [markdown]
# Eni said: use the wiki_pageviews duckdb.
# <br> You can follow the second tutorial, but swap the URL and the table name (instead of data_table use wiki_pageviews in the queries) and most of the queries will work, although the ones that do aggregation are a bit slow on this big database. It's better to select the rows that you need and save them in a CSV and then do the operations on the file.

# %% [markdown]
# This is from the DuckDB_Tutorial tutorial

# %% [markdown]
# I don't know what rows I need though

# %% [markdown]
# 1. Set up in Google Colab

# %%
import duckdb

# Placeholder for the database connection. It will be initialized later with the URL.
conn = duckdb.connect()
conn

# %%
# Install and Load the HTTPFS extension
# This is required to access remote files over the web (HTTP/S)
conn.execute("INSTALL httpfs;")
conn.execute("LOAD httpfs;")

# %% [markdown]
# 2. Connect to the Remote Database Source

# %%
# This is one of the several DuckDB databases hosted in the CS server.
# This database had the DPDP data for all countries.
database_url = "https://cs.wellesley.edu/~eni/duckdb/all_wiki.duckdb"

# Attach the remote file as a database named 'web_db' and start using it
try:
    conn.execute(f"ATTACH '{database_url}' AS web_db (READ_ONLY);")
    conn.execute("USE web_db;")
    print(f"Successfully attached database from: {database_url}")
except Exception as e:
    print(f"Error attaching database: {e}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Successfully attached database from: https://cs.wellesley.edu/~eni/duckdb/all_wiki.duckdb

# %% [markdown]
# 3. Show the Tables

# %%
query = "PRAGMA show_tables"
result = conn.sql(query)
result
# Out:
# ┌────────────────┐
# │      name      │
# │    varchar     │
# ├────────────────┤
# │ wiki_pageviews │
# └────────────────┘

# %%
table_name = "wiki_pageviews"
query = f"PRAGMA table_info('web_db.{table_name}');"

# We can apply the method .df() to the result of the query to convert it into a dataframe
column_info_df = conn.sql(query).df()
column_info_df
# Out:
#    cid          name     type  notnull dflt_value     pk
# 0    0          date     DATE    False       None  False
# 1    1  country_code  VARCHAR    False       None  False
# 2    2       project  VARCHAR    False       None  False
# 3    3       article  VARCHAR    False       None  False
# 4    4           qid  VARCHAR    False       None  False
# 5    5     pageviews   BIGINT    False       None  False

# %% [markdown]
# I want the date, country_code, article, qid, and pageviews

# %% [markdown]
# 4. SQL Commands for the Table

# %%
query_1 = """
SELECT * FROM wiki_pageviews
LIMIT 10;
"""
result_1 = conn.sql(query_1).df() # after executing, convert to df for better printout

result_1
# Out:
#         date country_code       project  \
# 0 2023-02-06           DZ  ar.wikipedia
# 1 2023-02-06           DZ  ar.wikipedia
# 2 2023-02-06           AR  en.wikipedia
# 3 2023-02-06           AR  es.wikipedia
# 4 2023-02-06           AR  es.wikipedia
# 5 2023-02-06           AR  es.wikipedia
# 6 2023-02-06           AR  es.wikipedia
# 7 2023-02-06           AR  es.wikipedia
# 8 2023-02-06           AR  es.wikipedia
# 9 2023-02-06           AR  es.wikipedia
#
#                                           article       qid  pageviews
# 0                         Ù
# ØªÙØ§Ø²Ù_Ø£Ø¶ÙØ§Ø¹    Q45867        108
# 1                                  Ø§ÙØ£ÙØ¯ÙØ³   Q123559        145
# 2                                    Robledo_Puch  Q3181149         99
# 3                                    Ojo_de_Horus   Q211286        135
# 4                             Estaciones_del_aÃ±o    Q24384        171
# 5                                Isla_de_Alcatraz   Q131354        126
# 6                                  Volkswagen_Gol   Q275442        148
# 7                            RÃ­o_Cuarto_(ciudad)   Q983451        179
# 8                                   Todo_Noticias  Q3244714        325
# 9  Tres_metros_sobre_el_cielo_(pelÃ­cula_de_2010)   Q944385        112

# %% [markdown]
# Now that I have my dataframe, I can get the specific information I need:
# - date
# - articles titles
# - qid
# - lang_code
# - country_code
# - pageviews

# %% [markdown]
# I also need to pick countries to look at

# %% [markdown]
# Let me filter by the date first. For this first part, I only want to look at the data for 1 month, so I am going to pick 2023-3

# %% [markdown]
# I think my date column is DATE objects ...

# %%
query_2 = """
SELECT date, country_code, project, article, qid, pageviews
FROM wiki_pageviews
WHERE DATE_TRUNC('month', date) = DATE '2023-03-01'
"""
df = conn.sql(query_2).df()

# %%
df.tail()
# Out:
#                date country_code       project                  article  \
# 11913520 2023-03-31           US  en.wikipedia             Jerry_Nadler
# 11913521 2023-03-31           US  en.wikipedia      68â95â99.7_rule
# 11913522 2023-03-31           US  fr.wikipedia                   France
# 11913523 2023-03-31           US  uk.wikipedia                  YouTube
# 11913524 2023-03-31           US  zh.wikipedia  æ­æ´å
# Â·ç¦å°æ©æ¯
#
#               qid  pageviews
# 11913520  Q505598        512
# 11913521  Q847822        530
# 11913522     Q142        685
# 11913523     Q866       3071
# 11913524    Q4653        557

# %% [markdown]
# Let me get the lang_code from the project title with pandas first

# %%
df[['lang_code', 'project']] = df['project'].str.split('.', n=1, expand=True)
df.tail()
# Out:
#                date country_code    project                  article      qid  \
# 11913520 2023-03-31           US  wikipedia             Jerry_Nadler  Q505598
# 11913521 2023-03-31           US  wikipedia      68â95â99.7_rule  Q847822
# 11913522 2023-03-31           US  wikipedia                   France     Q142
# 11913523 2023-03-31           US  wikipedia                  YouTube     Q866
# 11913524 2023-03-31           US  wikipedia  æ­æ´å
# Â·ç¦å°æ©æ¯    Q4653
#
#           pageviews lang_code
# 11913520        512        en
# 11913521        530        en
# 11913522        685        fr
# 11913523       3071        uk
# 11913524        557        zh

# %%
df["lang_code"] = df["project"][0][0:2]
df = df.drop('project', axis=1)
df.tail()
# Out:
#                date country_code                  article      qid  pageviews  \
# 11913520 2023-03-31           US             Jerry_Nadler  Q505598        512
# 11913521 2023-03-31           US      68â95â99.7_rule  Q847822        530
# 11913522 2023-03-31           US                   France     Q142        685
# 11913523 2023-03-31           US                  YouTube     Q866       3071
# 11913524 2023-03-31           US  æ­æ´å
# Â·ç¦å°æ©æ¯    Q4653        557
#
#          lang_code
# 11913520        ar
# 11913521        ar
# 11913522        ar
# 11913523        ar
# 11913524        ar

# %% [markdown]
# Okay, now I have my dataframe for March 2023, now I need to get my country dataframes

# %% [markdown]
# I want to include the US, Japan, UK, India, Germany - these are supposedly the countries that use wikipedia the most

# %%
USdf = df[(df['country_code'] == 'US')]
USdf.head()
# Out:
#            date country_code    project                         article  \
# 1681 2023-03-01           US  wikipedia                Kawasaki_disease
# 1682 2023-03-01           US  wikipedia  The_Elder_Scrolls_IV:_Oblivion
# 1683 2023-03-01           US  wikipedia             Marathon_Man_(film)
# 1684 2023-03-01           US  wikipedia               Eleanor_Tomlinson
# 1685 2023-03-01           US  wikipedia                      Alice_Neel
#
#            qid  pageviews lang_code
# 1681   Q265936        684        en
# 1682    Q49607        530        en
# 1683  Q1195727        523        en
# 1684  Q1582005        697        en
# 1685   Q460186       1044        en

# %%
JPdf = df[(df['country_code'] == 'JP')]
JPdf.head()
# Out:
#           date country_code    project                         article  \
# 951 2023-03-01           JP  wikipedia               Compartment_No._6
# 952 2023-03-01           JP  wikipedia                 çå®é«ç°æ´¾
# 953 2023-03-01           JP  wikipedia  ãã«ã¨ãã¹ãã¨å¬åç£
# 954 2023-03-01           JP  wikipedia                          ä¼½è¶
# 955 2023-03-01           JP  wikipedia               å½é72ç³»é»è»
#
#             qid  pageviews lang_code
# 951  Q107092356        104        en
# 952   Q10437214        167        ja
# 953     Q483263        285        ja
# 954      Q28084        299        ja
# 955   Q11421672        181        ja

# %%
UKdf = df[(df['country_code'] == 'GB')]
UKdf.head()
# Out:
#            date country_code    project                             article  \
# 1501 2023-03-01           GB  wikipedia                         Bill_Murray
# 1502 2023-03-01           GB  wikipedia              Russian_cruiser_Moskva
# 1503 2023-03-01           GB  wikipedia  Ashes_to_Ashes_(British_TV_series)
# 1504 2023-03-01           GB  wikipedia                         Green_Boots
# 1505 2023-03-01           GB  wikipedia                 Red_Dead_Redemption
#
#            qid  pageviews lang_code
# 1501    Q29250        386        en
# 1502  Q2992278         95        en
# 1503   Q725195        124        en
# 1504  Q3541506        162        en
# 1505   Q548203        194        en

# %%
INdf = df[(df['country_code'] == 'IN')]
INdf.head()
# Out:
#           date country_code    project  \
# 633 2023-03-01           IN  wikipedia
# 634 2023-03-01           IN  wikipedia
# 635 2023-03-01           IN  wikipedia
# 636 2023-03-01           IN  wikipedia
# 637 2023-03-01           IN  wikipedia
#
#                                            article         qid  pageviews  \
# 633                                   à¤
# à¤¶à¥à¤       Q8589        177
# 634  à¦ªà¦¾à¦ à¦¾à¦¨_(à¦à¦²à¦à§à¦à¦¿à¦¤à§à¦°)  Q114620212         98
# 635                            Hussain_Kuwajerwala    Q5949546        225
# 636                           Resident_Evil_(film)     Q153484        145
# 637                                  Sherilyn_Fenn     Q229993        109
#
#     lang_code
# 633        bh
# 634        bn
# 635        en
# 636        en
# 637        en

# %%
DEdf = df[(df['country_code'] == 'DE')]
DEdf.head()
# Out:
#           date country_code    project                          article  \
# 470 2023-03-01           DE  wikipedia                Carles_Puigdemont
# 471 2023-03-01           DE  wikipedia               Liste_von_Pistolen
# 472 2023-03-01           DE  wikipedia            Priyanka_Chopra_Jonas
# 473 2023-03-01           DE  wikipedia  Denis_Wladimirowitsch_Puschilin
# 474 2023-03-01           DE  wikipedia                         Dominica
#
#            qid  pageviews lang_code
# 470   Q4740163        101        br
# 471     Q60526        149        de
# 472    Q158957        215        de
# 473  Q16514790        109        de
# 474       Q784        211        de

# %% [markdown]
# Now I can create my csv file

# %%
import pandas as pd

# %%
csv_data = pd.concat([USdf, JPdf, UKdf, INdf, DEdf], ignore_index=True)

# %%
csv_data.tail()
# Out:
#               date country_code    project                  article  \
# 5636456 2023-03-31           DE  wikipedia    The_Glory_(TV_series)
# 5636457 2023-03-31           DE  wikipedia         Evan_Gershkovich
# 5636458 2023-03-31           DE  wikipedia  Ù
# Ø±ÛÙÛÙ_Ù
# ÙÙØ±Ù
# 5636459 2023-03-31           DE  wikipedia    ÙØ¯ÛÙ_Ø¨Ø§Ø²ÙÙØ¯
# 5636460 2023-03-31           DE  wikipedia          Fabio_Cannavaro
#
#                 qid  pageviews lang_code
# 5636456  Q113197148        211        en
# 5636457  Q117337455       1032        en
# 5636458       Q4616        121        fa
# 5636459  Q106396209         93        fa
# 5636460     Q102027        142        it

# %%
csv_data.drop(["project"], axis=1, inplace = True)

# %%
csv_data.head()
# Out:
#         date country_code                         article       qid  \
# 0 2023-03-01           US                Kawasaki_disease   Q265936
# 1 2023-03-01           US  The_Elder_Scrolls_IV:_Oblivion    Q49607
# 2 2023-03-01           US             Marathon_Man_(film)  Q1195727
# 3 2023-03-01           US               Eleanor_Tomlinson  Q1582005
# 4 2023-03-01           US                      Alice_Neel   Q460186
#
#    pageviews lang_code
# 0        684        en
# 1        530        en
# 2        523        en
# 3        697        en
# 4       1044        en

# %%
csv_data.to_csv("final-project-data.csv", index=False)

# %% [markdown]
# Now, my next step is to get all the qids for my articles

# %%
qid_df = pd.read_csv('final-project-data.csv')

# %%
qid_df = qid_df[["article", "qid"]]

# %%
qid_df.head()
# Out:
#                           article       qid
# 0                Kawasaki_disease   Q265936
# 1  The_Elder_Scrolls_IV:_Oblivion    Q49607
# 2             Marathon_Man_(film)  Q1195727
# 3               Eleanor_Tomlinson  Q1582005
# 4                      Alice_Neel   Q460186

# %% [markdown]
# Next, we can get script information about the articles using the code from the 4_get_wikidata file

# %%
import requests
import json, os

WIKIDATA_API_ENDPOINT = "https://www.wikidata.org/w/api.php"

def fetch_complete_entity_data(qid):
    """
    Fetches all available structured data for a single Wikidata entity (QID)
    using the official Wikibase API action=wbgetentities.

    Args:
        qid (str): The Wikidata Item ID (e.g., 'Q83285' for Durres).

    Returns:
        dict: The complete raw JSON data for the entity, or an error dictionary.
    """

    # Parameters for the MediaWiki API, using the 'wbgetentities' action
    params = {
        'action': 'wbgetentities',
        'ids': qid,
        'format': 'json',
        # Request all relevant data: claims (properties), labels, descriptions, sitelinks (Wikipedia links)
        'props': 'claims|labels|descriptions|sitelinks|aliases',
    }

    # Add a User-Agent header as recommended by Wikidata API policies
    # https://www.wikidata.org/wiki/Wikidata:Contact_the_development_team#User-Agent
    headers = {
        'User-Agent': 'Colab-Wikidata-Example/1.0 (https://colab.research.google.com; colab-user@example.com)'
    }

    try:
        response = requests.get(WIKIDATA_API_ENDPOINT, 
                                params=params, 
                                headers=headers, 
                                timeout=10)
        response.raise_for_status()  # Raises an HTTPError for bad responses (4xx or 5xx)

        data = response.json()

        # Check for potential errors in the API response structure
        if 'error' in data:
            return {"error": f"API Error for {qid}: {data['error']['info']}"}

        # The core data is nested under ['entities'][qid]
        entity_data = data.get('entities', {}).get(qid)

        if entity_data:
            return entity_data
        else:
            return {"error": f"Entity {qid} not found or no data returned."}

    except requests.exceptions.RequestException as e:
        return {"error": f"Network or API request error: {e}"}
    except json.JSONDecodeError:
        return {"error": "Failed to decode JSON response."}

# %% [markdown]
# I am going to run this on 1 qid to understand better how this code works:

# %%
fetch_complete_entity_data("Q265936")
# Out:
# {'type': 'item',
#  'id': 'Q265936',
#  'labels': {'de': {'language': 'de', 'value': 'Kawasaki-Syndrom'},
#   'ar': {'language': 'ar', 'value': 'داء كاواساكي'},
#   'ca': {'language': 'ca', 'value': 'malaltia de Kawasaki'},
#   'dv': {'language': 'dv', 'value': 'ކަވަސާކީ ސިންޑްރޯމް'},
#   'en': {'language': 'en', 'value': 'Kawasaki disease'},
#   'es': {'language': 'es', 'value': 'Enfermedad de Kawasaki'},
#   'et': {'language': 'et', 'value': 'Kawasaki haigus'},
#   'fa': {'language': 'fa', 'value': 'نشانگان کاوازاکی'},
#   'fi': {'language': 'fi', 'value': 'Kawasakin tauti'},
#   'fr': {'language': 'fr', 'value': 'maladie de Kawasaki'},
#   'he': {'language': 'he', 'value': 'מחלת קווסאקי'},
#   'hu': {'language': 'hu', 'value': 'Kawasaki-szindróma'},
#   'it': {'language': 'it', 'value': 'sindrome di Kawasaki'},
#   'ja': {'language': 'ja', 'value': '川崎病'},
#   'ms': {'language': 'ms', 'value': 'Penyakit Kawasaki'},
#   'nl': {'language': 'nl', 'value': 'Ziekte van Kawasaki'},
#   'pl': {'language': 'pl', 'value': 'Choroba Kawasakiego'},
#   'pt': {'language': 'pt', 'value': 'Síndrome de Kawasaki'},
#   'ru': {'language': 'ru', 'value': 'синдром Кавасаки'},
#   'sr': {'language': 'sr', 'value': 'Kavasakijeva bolest'},
#   'sv': {'language': 'sv', 'value': 'Kawasakis sjukdom'},
#   'th': {'language': 'th', 'value': 'โรคคะวะซะกิ'},
#   'tr': {'language': 'tr', 'value': 'Kawasaki hastalığı'},
#   'uk': {'language': 'uk', 'value': 'синдром Кавасакі'},
#   'zh': {'language': 'zh', 'value': '川崎氏病'},
#   'nb': {'language': 'nb', 'value': 'Kawasakis sykdom'},
#   'ro': {'language': 'ro', 'value': 'boala Kawasaki'},
#   'id': {'language': 'id', 'value': 'Penyakit Kawasaki'},
#   'mn': {'language': 'mn', 'value': '0'},
#   'cs': {'language': 'cs', 'value': 'Kawasakiho nemoc'},
#   'sl': {'language': 'sl', 'value': 'Kawasakijev sindrom'},
#   'or': {'language': 'or', 'value': 'କାୱାସାକି ଡିଜିଜ'},
#   'ta': {'language': 'ta', 'value': 'கவசாகி நோய்'},
#   'ko': {'language': 'ko', 'value': '가와사키병'},
#   'nn': {'language': 'nn', 'value': 'Kawasakis sjukdom'},
#   'el': {'language': 'el', 'value': 'Νόσος Kawasaki'},
#   'te': {'language': 'te', 'value': 'కవసాకి వ్యాధి'},
#   'hi': {'language': 'hi', 'value': 'कावासाकी रोग'},
#   'hy': {'language': 'hy', 'value': 'Կավասակի հիվանդություն'},
#   'eu': {'language': 'eu', 'value': 'Kawasaki gaixotasuna'},
#   'vi': {'language': 'vi', 'value': 'Bệnh Kawasaki'},
#   'lfn': {'language': 'lfn', 'value': 'Maladia de Kawasaki'},
#   'cy': {'language': 'cy', 'value': 'afiechyd Kawasaki'},
#   'mk': {'language': 'mk', 'value': 'Кавасакиева болест'},
#   'si': {'language': 'si', 'value': 'කවසකි රෝගය'},
#   'kk': {'language': 'kk', 'value': 'Кавасаки ауруы'},
#   'eo': {'language': 'eo', 'value': 'malsano de Kavasaki'},
#   'ga': {'language': 'ga', 'value': 'galar Kawasaki'},
#   'gl': {'language': 'gl', 'value': 'Doenza de Kawasaki'},
#   'az': {'language': 'az', 'value': 'Kavasaki xəstəliyi'},
#   'azb': {'language': 'azb', 'value': 'کاواساکی مریضلیگی'},
#   'vec': {'language': 'vec', 'value': 'sìndrome de Kawasaki'},
#   'bg': {'language': 'bg', 'value': 'Болест на Кавазаки'}},
#  'descriptions': {'id': {'language': 'id',
#    'value': 'Penyakit Kawasaki adalah penyakit autoimunitas dimana pembuluh darah berukuran sedang diseluruh tubuh menjadi meradang.'},
#   'en': {'language': 'en',
#    'value': 'human disease in which blood vessels throughout the body become inflamed'},
#   'cs': {'language': 'cs', 'value': 'systémové onemocnění pojivové tkáně'},
#   'uk': {'language': 'uk', 'value': 'клінічний синдром невідомого генезу'},
#   'de': {'language': 'de', 'value': 'Krankheit'},
#   'ar': {'language': 'ar', 'value': 'مرض يصيب الإنسان'},
#   'it': {'language': 'it',
#    'value': 'vasculite infantile delle arterie di media e piccola dimensione che colpisce soprattutto le arterie coronarie'},
#   'fi': {'language': 'fi', 'value': 'sairaus'},
#   'sv': {'language': 'sv', 'value': 'vaskulitsjukdom'},
#   'ja': {'language': 'ja', 'value': '小児科医・川崎富作によって発見された発熱性疾患'},
#   'fr': {'language': 'fr', 'value': 'maladie infantile'},
#   'he': {'language': 'he',
#    'value': 'דלקת חריפה בכלי הדם הפוגעת בעיקר בפעוטות'},
#   'eo': {'language': 'eo', 'value': 'homa malsano'},
#   'hu': {'language': 'hu',
#    'value': 'a kis és közepes méretű artériák gyulladásával járó megbetegedés'},
#   'ms': {'language': 'ms', 'value': 'sindrom nodus limfa pada kanak-kanak'},
#   'ru': {'language': 'ru', 'value': 'Детский синдром'},
#   'pt': {'language': 'pt',
#    'value': 'doença humana na qual os vasos sanguíneos de todo o corpo ficam inflamados'},
#   'nl': {'language': 'nl', 'value': 'Een zeldzame hart- en vaten syndroom'},
#   'es': {'language': 'es',
#    'value': 'enfermedad humana en la que los vasos sanguíneos de todo el cuerpo se inflaman'},
#   'ro': {'language': 'ro',
#    'value': 'boală umană în care vasele de sânge din tot corpul se inflamează'}},
#  'aliases': {'en': [{'language': 'en', 'value': "Kawasaki's disease"},
#    {'language': 'en', 'value': 'MLNS'},
#    {'language': 'en', 'value': 'acute febrile MCLS'},
#    {'language': 'en',
#     'value': 'acute febrile mucocutaneous lymph node syndrome [MCLS]'},
#    {'language': 'en', 'value': 'mucocutaneous lymph node syndrome'},
#    {'language': 'en', 'value': 'Kawasaki disease, KD'},
#    {'language': 'en',
#     'value': 'acute febrile mucocutaneous lymph node syndrome'},
#    {'language': 'en', 'value': 'Infantile Polyarteritis Nodosa'},
#    {'language': 'en', 'value': 'KAWASAKI DISEASE'},
#    {'language': 'en', 'value': 'Kd'},
#    {'language': 'en', 'value': 'Infantile Polyarteritis'}],
#   'cs': [{'language': 'cs', 'value': 'Kawasakiho choroba'}],
#   'uk': [{'language': 'uk', 'value': 'хвороба Кавасакі'}],
#   'nn': [{'language': 'nn', 'value': 'Kawasakis syndrom'},
#    {'language': 'nn', 'value': 'mukokutant lymfeknutesyndrom'}],
#   'el': [{'language': 'el', 'value': 'Νόσος Καβασάκι'}],
#   'ar': [{'language': 'ar', 'value': 'مرض كاوازاكي'},
#    {'language': 'ar', 'value': 'متلازمة كاواساكي'}],
#   'fr': [{'language': 'fr', 'value': 'syndrome lympho-cutanéo-muqueux'},
#    {'language': 'fr', 'value': 'syndrome adéno-cutanéo-muqueux'}],
#   'zh': [{'language': 'zh', 'value': '川崎病'}]},
#  'claims': {'P373': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P373',
#      'hash': '79e1a6a2a30f70d3225175af4114cca8642e8bcc',
#      'datavalue': {'value': 'Kawasaki disease', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'q265936$426F2DEA-EF39-4DBC-9CAD-F87322C470C2',
#     'rank': 'normal'}],
#   'P492': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P492',
#      'hash': 'd2881975144953d04a507998ab83515fcbc4a879',
#      'datavalue': {'value': '611775', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$A6BC3218-D4FF-4C63-AB62-EC8B45D2E4D3',
#     'rank': 'normal',
#     'references': [{'hash': 'c79a532087b7df34fda8180f39ba3b24c00dff25',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '2d605fd668b56941351731a068d461b9fdceee72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 5282129,
#            'id': 'Q5282129'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '9c76347c2450b1d6fc4aae90440c7aeb7cf57967',
#          'datavalue': {'value': {'time': '+2019-05-15T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P699': [{'snaktype': 'value',
#          'property': 'P699',
#          'hash': 'a10ff691ab8023b81b7b337300e8118eab6881ae',
#          'datavalue': {'value': 'DOID:13378', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P699']}]}],
#   'P604': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P604',
#      'hash': '051e09b393f1c69c472ba18061b61af91bf483ce',
#      'datavalue': {'value': '000989', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q265936$0184771F-7244-4D50-AED7-6B695D04E106',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P557': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P557',
#      'hash': '809e10f64888baf4e3b92fdfe0f697cba2c58bb3',
#      'datavalue': {'value': '7121', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q265936$923FEB47-7BA3-4C95-B2C6-6D3394613DFA',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P673': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P673',
#      'hash': 'd413fd435c988ec25744040c1d9b7c6feeac4ee4',
#      'datavalue': {'value': '965367', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q265936$7B472755-7486-43F8-937F-9F85840D4335',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P349': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P349',
#      'hash': '58777c11f37240283b9a9700ac34b532ed978ad6',
#      'datavalue': {'value': '00565244', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$D41121F5-2BD7-41F5-A5CD-4C6DBEC3CCB4',
#     'rank': 'normal'}],
#   'P646': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P646',
#      'hash': '3c1b5b10cca62ee3b850b59eb1e3e6ee1036c355',
#      'datavalue': {'value': '/m/040k6g', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$71D1BCE3-B719-467C-B159-E5D3634969FD',
#     'rank': 'normal',
#     'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 15241312,
#            'id': 'Q15241312'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P577': [{'snaktype': 'value',
#          'property': 'P577',
#          'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#          'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P577']}]}],
#   'P18': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P18',
#      'hash': '267c67b84efd23d944917d34fe53c8c8c0c7cab4',
#      'datavalue': {'value': 'Kawasaki Disease.png', 'type': 'string'},
#      'datatype': 'commonsMedia'},
#     'type': 'statement',
#     'id': 'Q265936$FA51ADF0-DF3A-410C-99AC-AB18EF749B46',
#     'rank': 'normal',
#     'references': [{'hash': '732ec1c90a6f0694c7db9a71bf09fe7f2b674172',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '9123b0de1cc9c3954366ba797d598e4e1ea4146f',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 10000,
#            'id': 'Q10000'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P1296': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1296',
#      'hash': 'c4f3c781f502296ceaf5dca29e6268b96793bb9c',
#      'datavalue': {'value': '0262801', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$49AF28E2-5D5C-4E74-9C2A-D7754A46696D',
#     'rank': 'normal',
#     'references': [{'hash': 'b3fd5e254143d8b52cd96cff43af9af5e3a82358',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'f13c99a16441677ec69fcea23f221d866f1fc98f',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 199693,
#            'id': 'Q199693'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P1461': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1461',
#      'hash': '94fb5b326aeee1361d4ddfac95ec3c7e6ee88edd',
#      'datavalue': {'value': 'kawasaki-disease-pro', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$E3226F89-B1EE-4B24-BFA4-3D6D728C8CE6',
#     'rank': 'normal',
#     'references': [{'hash': 'b6c091235d960edba99d0c802aa1c5635af57865',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '3c49fe7c46bf6d79eced69dbdd4ab232d5122a99',
#          'datavalue': {'value': 'http://www.patient.co.uk/patientplus/k.htm',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]}],
#   'P699': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P699',
#      'hash': 'a10ff691ab8023b81b7b337300e8118eab6881ae',
#      'datavalue': {'value': 'DOID:13378', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$267F139A-0FC3-4C52-BCE6-EDD4F1732122',
#     'rank': 'normal',
#     'references': [{'hash': '0458e327db229561c0821f6874395c6a4e9f49cf',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '2d605fd668b56941351731a068d461b9fdceee72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 5282129,
#            'id': 'Q5282129'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '1404ed43c31d4e2b8b834d065951afce7838bfe2',
#          'datavalue': {'value': {'time': '+2020-11-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P699': [{'snaktype': 'value',
#          'property': 'P699',
#          'hash': 'a10ff691ab8023b81b7b337300e8118eab6881ae',
#          'datavalue': {'value': 'DOID:13378', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P699']}]}],
#   'P1748': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1748',
#      'hash': '09f5931d56171d9c5827a589eeb29db2312f98d8',
#      'datavalue': {'value': 'C34825', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'Q265936$EE731D6B-546F-450F-99A2-52B6826824E9',
#     'rank': 'normal',
#     'references': [{'hash': 'c79a532087b7df34fda8180f39ba3b24c00dff25',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '2d605fd668b56941351731a068d461b9fdceee72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 5282129,
#            'id': 'Q5282129'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '9c76347c2450b1d6fc4aae90440c7aeb7cf57967',
#          'datavalue': {'value': {'time': '+2019-05-15T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P699': [{'snaktype': 'value',
#          'property': 'P699',
#          'hash': 'a10ff691ab8023b81b7b337300e8118eab6881ae',
#          'datavalue': {'value': 'DOID:13378', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P699']}]}],
#   'P279': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P279',
#      'hash': '43666fc8bda57d510dc29ec632be45c0c9ba7a48',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 3269466,
#        'id': 'Q3269466'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$893BC574-B637-455D-9D17-8DE65FF22EF7',
#     'rank': 'normal',
#     'references': [{'hash': '0458e327db229561c0821f6874395c6a4e9f49cf',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '2d605fd668b56941351731a068d461b9fdceee72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 5282129,
#            'id': 'Q5282129'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '1404ed43c31d4e2b8b834d065951afce7838bfe2',
#          'datavalue': {'value': {'time': '+2020-11-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P699': [{'snaktype': 'value',
#          'property': 'P699',
#          'hash': 'a10ff691ab8023b81b7b337300e8118eab6881ae',
#          'datavalue': {'value': 'DOID:13378', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P699']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P279',
#      'hash': 'e9c8a95f3891162712d0172fe302887dcff15ecc',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 3843811,
#        'id': 'Q3843811'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$4908ECBD-786F-4619-9F60-0B3A005660DE',
#     'rank': 'normal',
#     'references': [{'hash': '4ce0e665144c0a96c9100b5ba9391b3c66506ad3',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'e0d9e28e955002e1f784eefdebc166c9db6c9302',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 55345445,
#            'id': 'Q55345445'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'ac825f004b713150f93ad70d6bfc997b17afa386',
#          'datavalue': {'value': {'time': '+2018-07-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P5270': [{'snaktype': 'value',
#          'property': 'P5270',
#          'hash': '2f9461a6d6e1c17e3c22448f6f9198248f576b2e',
#          'datavalue': {'value': 'MONDO_0012727', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P5270']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P279',
#      'hash': '8019daf2f03ba5efc2807a9c3d4896f963ff5aa2',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 55785505,
#        'id': 'Q55785505'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$FAB4394D-E46B-45CD-9851-9BE90597F507',
#     'rank': 'normal',
#     'references': [{'hash': '4ce0e665144c0a96c9100b5ba9391b3c66506ad3',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'e0d9e28e955002e1f784eefdebc166c9db6c9302',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 55345445,
#            'id': 'Q55345445'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'ac825f004b713150f93ad70d6bfc997b17afa386',
#          'datavalue': {'value': {'time': '+2018-07-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P5270': [{'snaktype': 'value',
#          'property': 'P5270',
#          'hash': '2f9461a6d6e1c17e3c22448f6f9198248f576b2e',
#          'datavalue': {'value': 'MONDO_0012727', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P5270']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P279',
#      'hash': '2ed2c3a2fae28ff6da5fe79126ea01d7ac271850',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 12136,
#        'id': 'Q12136'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$C5BC8F08-A447-463E-A2ED-77BB8E4075C0',
#     'rank': 'normal'}],
#   'P1995': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1995',
#      'hash': '8eecf2d25693f6487102a8054f66d9fb2a3e39a2',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 101929,
#        'id': 'Q101929'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$8251F79B-7D09-433F-9128-82982483763D',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P1995',
#      'hash': 'dbd65afd5a16f7d0effec92128aa49bf21fed600',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1919436,
#        'id': 'Q1919436'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$041040b4-46c2-d3a0-2e99-a3521023f305',
#     'rank': 'normal'}],
#   'P2293': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': '7a8563d76d5daab781aa36d7d0f9818f85140798',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18052047,
#        'id': 'Q18052047'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$6F6D5229-A071-4ACD-A132-FC37F37965E7',
#     'rank': 'normal',
#     'references': [{'hash': '7319e3ab6be861870666027255d43783d7bc4666',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '65349a7d7264bb76d004d27b7a1e3d7052d37757',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=151742',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': '2081a3accca59e7c171df774b04b592258fed4e4',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=PPM1L',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': '3db0b2b89f2b871bacd63230c5bbf21641ed4981',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 29417067,
#            'id': 'Q29417067'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': '9d407f646c14b1848af6c651dcf470e2aa418e83',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18048257,
#        'id': 'Q18048257'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$89A65C55-1B12-42CE-A32F-974648CC1C34',
#     'rank': 'normal',
#     'references': [{'hash': '8752e76bc8870cc533f1b9c3e2200e10550255bb',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'dc390026d907999ef8836a7c3238db32267505fc',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=90390',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': '696b43892ed216db48a97b7144f250db66feca35',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=MED30',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': '3db0b2b89f2b871bacd63230c5bbf21641ed4981',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 29417067,
#            'id': 'Q29417067'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': '38b1bfa41da90322e92c0fbaa8b4ff0e70582d26',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 17927782,
#        'id': 'Q17927782'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$C93016C9-7D2D-432D-982A-A021232F8A46',
#     'rank': 'normal',
#     'references': [{'hash': '2333b5a6085e57110215d209a9b4643b7e7ee161',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'd982cdd7ef81dc762a1c329950a0f2a61b088aa2',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=2212',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'ae927a4a6d601aafdf51e98cfb88adfa8ad45e66',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=FCGR2A',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': '7dd35c11201b56c69267a54f8e576991d1bade24',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 29417017,
#            'id': 'Q29417017'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': '396d482c74f6e1da70543371eda3bf845eea7418',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18040605,
#        'id': 'Q18040605'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$C766B81E-AEB6-47E8-BD3E-B7803ADA4D7F',
#     'rank': 'normal',
#     'references': [{'hash': '40d68c2ef3c26756af47ac1e0cf03174e5eaa020',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '2cbd3fe04b6ba985d2931bdc1aad13f9527345f5',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=53339',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': '773a837a6abbdd6b0bedbc4260ea589c559b9647',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=BTBD1',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'f545db329c10acd8da2f80419623094e0b184e09',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 28943550,
#            'id': 'Q28943550'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': '00628db443debadf9c577559bc69235e9e3924bd',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18042944,
#        'id': 'Q18042944'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$F026F22A-0403-4964-9D5F-B6F4A1D91A9B',
#     'rank': 'normal',
#     'references': [{'hash': '4dba0161e024c45699a68d3089bcac2a2075fd5c',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'e2a79abd1ea865e798e93f613be11dbacc2f6c62',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=57162',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': '30edac970bd0651f71a6a14d21a2a5c94d078132',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=PELI1',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'b9f1706dea4213b3742b085d8c644248cb719abd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 29417090,
#            'id': 'Q29417090'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': 'ef18fc4196cc5615cef832c6216437318a8e0a88',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18053762,
#        'id': 'Q18053762'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$248C7519-B647-4FB5-90C9-FF8772240206',
#     'rank': 'normal',
#     'references': [{'hash': 'd3f295144ccb1fe28726548aa6e7373d66b42d64',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'a5ed1e897ae5839f4616f0c3a294c5a31e490dac',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=254827',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': '5a0693371ecf2eb7f298b8fce98df0c930d1a5e3',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=NAALADL2',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': '7481952dde70783fe41a21a1ff851dc24399d324',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21563323,
#            'id': 'Q21563323'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': 'e4e5d6a5c74e76d4133822e544d962b2c6500685',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 17832572,
#        'id': 'Q17832572'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P459': [{'snaktype': 'value',
#        'property': 'P459',
#        'hash': '69b2441208f1883f31bf1846ef18ee657947e0bf',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1098876,
#          'id': 'Q1098876'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       {'snaktype': 'value',
#        'property': 'P459',
#        'hash': 'd371e947e3947eae31e94b95dd06f3037c86efa5',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23190853,
#          'id': 'Q23190853'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P459'],
#     'id': 'Q265936$63FEA5F7-D988-4FF7-9B05-0FDF5F68AAC4',
#     'rank': 'normal',
#     'references': [{'hash': '8e394fbe3301c05de5949c85324e06cc726d9aac',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'ec54b64a59640da30f4196f6ac17942795e3206a',
#          'datavalue': {'value': 'https://gemma.msl.ubc.ca/phenotypes.html?phenotypeUrlId=DOID_13378&ncbiId=463',
#           'type': 'string'},
#          'datatype': 'url'},
#         {'snaktype': 'value',
#          'property': 'P854',
#          'hash': '5dfcf44a9e479f8312d5e58583906bf9fa0d8477',
#          'datavalue': {'value': 'http://www.genome.gov/gwastudies/index.cfm?gene=ZFHX3',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'daa9af59eacd0a20502a99436a639cacaa7bb6a0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 22330995,
#            'id': 'Q22330995'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         {'snaktype': 'value',
#          'property': 'P248',
#          'hash': '7481952dde70783fe41a21a1ff851dc24399d324',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 21563323,
#            'id': 'Q21563323'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '8d8b764b1d6e36693cd784db63ec241be2752d88',
#          'datavalue': {'value': {'time': '+2020-05-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2293',
#      'hash': '05b3326573702c48230d51e251c9d792b9318199',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18046680,
#        'id': 'Q18046680'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$D13F63F8-61CB-4921-913F-DBE94FEF435E',
#     'rank': 'normal',
#     'references': [{'hash': '44bfb889182e3e1834480a59f9d5c5ad23700110',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'a704412e9f77032ada72edf95265a0b30e5392a5',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 905695,
#            'id': 'Q905695'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P352': [{'snaktype': 'value',
#          'property': 'P352',
#          'hash': 'f29749b16a99250a81ae3e707f58f0c6fa260839',
#          'datavalue': {'value': 'Q96DU7', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '507a061386ed8d4e27de5446c6a1c54b75654480',
#          'datavalue': {'value': {'time': '+2019-08-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P352', 'P813']}]}],
#   'P2888': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2888',
#      'hash': '554813c768e015b2af1d25fcb731d0aa28a863e1',
#      'datavalue': {'value': 'http://purl.obolibrary.org/obo/DOID_13378',
#       'type': 'string'},
#      'datatype': 'url'},
#     'type': 'statement',
#     'id': 'Q265936$888469BC-D850-4FE2-B63F-33CF3B850F15',
#     'rank': 'normal',
#     'references': [{'hash': '0458e327db229561c0821f6874395c6a4e9f49cf',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '2d605fd668b56941351731a068d461b9fdceee72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 5282129,
#            'id': 'Q5282129'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '1404ed43c31d4e2b8b834d065951afce7838bfe2',
#          'datavalue': {'value': {'time': '+2020-11-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P699': [{'snaktype': 'value',
#          'property': 'P699',
#          'hash': 'a10ff691ab8023b81b7b337300e8118eab6881ae',
#          'datavalue': {'value': 'DOID:13378', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P699']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2888',
#      'hash': 'f154161b1170d883aa77a0d93cfe3d182813d166',
#      'datavalue': {'value': 'http://identifiers.org/doid/DOID:13378',
#       'type': 'string'},
#      'datatype': 'url'},
#     'type': 'statement',
#     'id': 'Q265936$1C1E71E7-B52E-4FA5-BE79-2A829DF29B65',
#     'rank': 'normal',
#     'references': [{'hash': 'a1c7d87056e7b4d72d80d1b68562f9dcc952596f',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '5d999174dda06cba7b1b89d5ad561656db9bf89d',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 16335166,
#            'id': 'Q16335166'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '6c3308f0f1c6b4bb7c44c46667026470d3958322',
#          'datavalue': {'value': 'https://registry.identifiers.org/registry/doid',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P248', 'P854']}]}],
#   'P2892': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2892',
#      'hash': '03305e1171cb6c4c93ccfcd92693a64f81765eaf',
#      'datavalue': {'value': 'C2936917', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P4390': [{'snaktype': 'value',
#        'property': 'P4390',
#        'hash': '97a9b264c1cbc8ac9d7b66aad848f24c10d8c118',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 39893184,
#          'id': 'Q39893184'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P4390'],
#     'id': 'Q265936$A697623A-1568-49A3-9BF9-AB467B9BE307',
#     'rank': 'normal',
#     'references': [{'hash': '4ce0e665144c0a96c9100b5ba9391b3c66506ad3',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'e0d9e28e955002e1f784eefdebc166c9db6c9302',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 55345445,
#            'id': 'Q55345445'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'ac825f004b713150f93ad70d6bfc997b17afa386',
#          'datavalue': {'value': {'time': '+2018-07-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
# ...
#     'rank': 'normal'}],
#   'P665': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P665',
#      'hash': 'c02e0833bb879012ff74c0f8e4aec20e478ea272',
#      'datavalue': {'value': 'H01718', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$4533F5E8-D37B-4E02-9A1D-AB7C57768B68',
#     'rank': 'normal'}],
#   'P7807': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7807',
#      'hash': '502707929dd789af4907b7629b6936d98d5aba55',
#      'datavalue': {'value': '540285662', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$6A64BE06-F7DE-4C1D-8C11-6EE52961030B',
#     'rank': 'normal'}],
#   'P7329': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7329',
#      'hash': '4fe6a9b7f332247709b4733260ff7436a733d341',
#      'datavalue': {'value': '4A44.5', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': 'a282e961c5daeb1fa5271fdd1dd4ee60d8fa0712',
#        'datavalue': {'value': 'Mucocutaneous lymph node syndrome',
#         'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q265936$1c9d750f-dae6-4d48-af17-d5c4bd11421e',
#     'rank': 'normal'}],
#   'P443': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P443',
#      'hash': '6d950bfaf4a0448c1226c9a5723e61f0bfa9c303',
#      'datavalue': {'value': 'LL-Q33810 (ori)-Psubhashish-କାୱାସାକି ଡିଜିଜ.wav',
#       'type': 'string'},
#      'datatype': 'commonsMedia'},
#     'type': 'statement',
#     'qualifiers': {'P407': [{'snaktype': 'value',
#        'property': 'P407',
#        'hash': 'cf3e7f106e2919f193ff385c8938da590d316cf0',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 33810,
#          'id': 'Q33810'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P407'],
#     'id': 'Q265936$ee4334cf-024c-4bb5-b496-71675310fd00',
#     'rank': 'normal',
#     'references': [{'hash': '9a5680520714d789fa149592bbcd472a593b94cb',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '10dae3afb389d9e63183b0ee98a5d0e9df37fccb',
#          'datavalue': {'value': 'https://lingualibre.org/wiki/Q648180',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]}],
#   'P8189': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8189',
#      'hash': 'ed715208756837bf1b6afa8598245b2340d538d6',
#      'datavalue': {'value': '987007543956505171', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$C55595A1-7578-4AE9-8C3B-B46D25290208',
#     'rank': 'normal',
#     'references': [{'hash': 'c8a47202c92936005b390eb36ddd267921b51f43',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '0ea73b3596b49258a7b7ec6495950779b99e875d',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 188915,
#            'id': 'Q188915'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P10283': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P10283',
#      'hash': '26af2c9e15ec43ec252e70462dd46fdb965b481f',
#      'datavalue': {'value': 'C2910812759', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$967CA54F-93DF-4D29-A4AE-34F4AE197F14',
#     'rank': 'normal',
#     'references': [{'hash': 'c13ba4d7902ead2693f79396bc25bd35d4d14030',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '4a4f26a5361b5707266e48e425bf2be2f99fd2ab',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 107507571,
#            'id': 'Q107507571'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '435834d08182bb9f3dbe974ba9840af0f12899cc',
#          'datavalue': {'value': {'time': '+2022-01-26T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'a4a4bf53f22268815c51ec10fed608da703c9c7f',
#          'datavalue': {'value': 'https://docs.openalex.org/download-snapshot/snapshot-data-format',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P248', 'P813', 'P854']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P10283',
#      'hash': '870523dd72f857d813b75474458c8a88215209ab',
#      'datavalue': {'value': 'C2781423770', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$8B234F4E-D99F-4E6A-9B67-2178B4CF6CC2',
#     'rank': 'normal',
#     'references': [{'hash': 'c13ba4d7902ead2693f79396bc25bd35d4d14030',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '4a4f26a5361b5707266e48e425bf2be2f99fd2ab',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 107507571,
#            'id': 'Q107507571'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '435834d08182bb9f3dbe974ba9840af0f12899cc',
#          'datavalue': {'value': {'time': '+2022-01-26T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'a4a4bf53f22268815c51ec10fed608da703c9c7f',
#          'datavalue': {'value': 'https://docs.openalex.org/download-snapshot/snapshot-data-format',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P248', 'P813', 'P854']}]}],
#   'P2347': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2347',
#      'hash': 'a3612c9533881dffdef2331f0bc8313ff939fa74',
#      'datavalue': {'value': '9205', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': '63f34e04d1a0e984fd4837b60d7b29416dbc46d6',
#        'datavalue': {'value': 'Kawasakin tauti', 'type': 'string'},
#        'datatype': 'string'},
#       {'snaktype': 'value',
#        'property': 'P1810',
#        'hash': '8fb42d97a67e69113a92b5a90520bd49919f24ef',
#        'datavalue': {'value': 'Kawasakis sjukdom', 'type': 'string'},
#        'datatype': 'string'},
#       {'snaktype': 'value',
#        'property': 'P1810',
#        'hash': 'ad401921914a18f0a0a4ea167936f0eb27d6f2b9',
#        'datavalue': {'value': 'Kawasaki disease', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q265936$DD57DB92-B32E-4E08-A5EE-1C82E05730C5',
#     'rank': 'normal',
#     'references': [{'hash': '2e685336fc04a47ae351a9546a83fc03b8d918b2',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '7133f11674741f52cadaae6029068fad9cbb52e3',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 89345680,
#            'id': 'Q89345680'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'fec7a8067d3534778e5dd4322b3150c8398e5b59',
#          'datavalue': {'value': {'time': '+2022-02-02T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P813']}]}],
#   'P31': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P31',
#      'hash': 'bcbc52012025a062fb4454f65addb4fc699386ca',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 112193867,
#        'id': 'Q112193867'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q265936$B06A6CF3-C32B-4A75-AB02-5D514BAEF0EA',
#     'rank': 'normal'}],
#   'P11143': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P11143',
#      'hash': '49a74cca59fedc6bcb6576ba9107916944cc3322',
#      'datavalue': {'value': 'Kawasaki disease', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$02E3B16B-7E8F-4DAC-A749-933D5C630FE7',
#     'rank': 'normal'}],
#   'P4233': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P4233',
#      'hash': 'fc5b94f431aad4b8cfdeb9c51edfd1b4816734aa',
#      'datavalue': {'value': 'kawasaki-disease', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$614531f6-4656-e0a6-3460-ce84da2023ab',
#     'rank': 'normal'}],
#   'P11956': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P11956',
#      'hash': '1b3a4b11a5281a266a8eb9f75cc9c9c354728c12',
#      'datavalue': {'value': '0004246', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$06B16E70-E812-4212-BE6E-C64734D656C5',
#     'rank': 'normal',
#     'references': [{'hash': '503d5a1c1b3dea221e8e26226a82763e8a2b6754',
#       'snaks': {'P887': [{'snaktype': 'value',
#          'property': 'P887',
#          'hash': '8c2aa2b706677f06d81a491e0b3ca0f07de7b5f4',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 121546317,
#            'id': 'Q121546317'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P887']}]}],
#   'P4527': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P4527',
#      'hash': '2f9aef99e745d94a5fd5d6e782b530c76a08aa99',
#      'datavalue': {'value': '452750', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': 'ad401921914a18f0a0a4ea167936f0eb27d6f2b9',
#        'datavalue': {'value': 'Kawasaki disease', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q265936$FC485094-4BEA-45A9-B1D7-3D7C942EFC00',
#     'rank': 'normal'}],
#   'P11430': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P11430',
#      'hash': '4bd19bcfd331101b4db1fc3f81bb58486e27ed5a',
#      'datavalue': {'value': 'DI-02892', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$d06f54ac-4ca4-d6cc-02b0-cffe99c2db25',
#     'rank': 'normal'}],
#   'P5270': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P5270',
#      'hash': '2f9461a6d6e1c17e3c22448f6f9198248f576b2e',
#      'datavalue': {'value': 'MONDO_0012727', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$467CF5BE-B1FB-45AE-847E-D6629C2C89C9',
#     'rank': 'normal'}],
#   'P12086': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P12086',
#      'hash': '6276ae6da4ad2700d451fe9e72f753112f5b9841',
#      'datavalue': {'value': 'Ziekte_van_Kawasaki', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$557612F2-EBE6-4D53-AF81-DD855B58020A',
#     'rank': 'normal'}],
#   'P12385': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P12385',
#      'hash': 'd8b211442b86ac226d92dffdf4af2a03cbe0b6db',
#      'datavalue': {'value': 'malaltia-de-kawasaki', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$7639f0d2-dc34-4e0a-b061-aa91eaa393b3',
#     'rank': 'normal'}],
#   'P13591': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P13591',
#      'hash': '60f10651fcaec5cc5a6305f1e45c969f51748cae',
#      'datavalue': {'value': 'concept/75bcd2f7-c394-412f-9a91-aa0855d38960',
#       'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q265936$8009335C-0DC9-4292-A45F-67CDF497A02C',
#     'rank': 'normal'}]},
#  'sitelinks': {'arwiki': {'site': 'arwiki',
#    'title': 'داء كاواساكي',
#    'badges': []},
#   'azbwiki': {'site': 'azbwiki', 'title': 'کاواساکی مریضلیگی', 'badges': []},
#   'azwiki': {'site': 'azwiki', 'title': 'Kavasaki xəstəliyi', 'badges': []},
#   'bgwiki': {'site': 'bgwiki', 'title': 'Болест на Кавазаки', 'badges': []},
#   'cawiki': {'site': 'cawiki', 'title': 'Malaltia de Kawasaki', 'badges': []},
#   'commonswiki': {'site': 'commonswiki',
#    'title': 'Category:Kawasaki disease',
#    'badges': []},
#   'dewiki': {'site': 'dewiki', 'title': 'Kawasaki-Syndrom', 'badges': []},
#   'dvwiki': {'site': 'dvwiki', 'title': 'ކަވަސާކީ ސިންޑްރޯމް', 'badges': []},
#   'elwiki': {'site': 'elwiki', 'title': 'Νόσος Καβασάκι', 'badges': []},
#   'enwiki': {'site': 'enwiki', 'title': 'Kawasaki disease', 'badges': []},
#   'eswiki': {'site': 'eswiki',
#    'title': 'Enfermedad de Kawasaki',
#    'badges': []},
#   'etwiki': {'site': 'etwiki', 'title': 'Kawasaki haigus', 'badges': []},
#   'euwiki': {'site': 'euwiki', 'title': 'Kawasaki gaixotasun', 'badges': []},
#   'fawiki': {'site': 'fawiki', 'title': 'بیماری کاوازاکی', 'badges': []},
#   'fiwiki': {'site': 'fiwiki', 'title': 'Kawasakin tauti', 'badges': []},
#   'frwiki': {'site': 'frwiki', 'title': 'Maladie de Kawasaki', 'badges': []},
#   'glwiki': {'site': 'glwiki', 'title': 'Doenza de Kawasaki', 'badges': []},
#   'hewiki': {'site': 'hewiki', 'title': 'מחלת קווסאקי', 'badges': []},
#   'hiwiki': {'site': 'hiwiki', 'title': 'कावासाकी रोग', 'badges': []},
#   'huwiki': {'site': 'huwiki', 'title': 'Kawasaki-szindróma', 'badges': []},
#   'hywiki': {'site': 'hywiki',
#    'title': 'Կավասակիի հիվանդություն',
#    'badges': []},
#   'idwiki': {'site': 'idwiki', 'title': 'Penyakit Kawasaki', 'badges': []},
#   'itwiki': {'site': 'itwiki', 'title': 'Sindrome di Kawasaki', 'badges': []},
#   'jawiki': {'site': 'jawiki', 'title': '川崎病', 'badges': []},
#   'kkwiki': {'site': 'kkwiki', 'title': 'Кавасаки ауруы', 'badges': []},
#   'kowiki': {'site': 'kowiki', 'title': '가와사키병', 'badges': []},
#   'lfnwiki': {'site': 'lfnwiki', 'title': 'Maladia de Kawasaki', 'badges': []},
#   'mkwiki': {'site': 'mkwiki', 'title': 'Кавасакиева болест', 'badges': []},
#   'mswiki': {'site': 'mswiki', 'title': 'Penyakit Kawasaki', 'badges': []},
#   'nlwiki': {'site': 'nlwiki', 'title': 'Ziekte van Kawasaki', 'badges': []},
#   'nowiki': {'site': 'nowiki', 'title': 'Kawasakis sykdom', 'badges': []},
#   'orwiki': {'site': 'orwiki', 'title': 'କାୱାସାକି ଡିଜିଜ', 'badges': []},
#   'plwiki': {'site': 'plwiki', 'title': 'Choroba Kawasakiego', 'badges': []},
#   'ptwiki': {'site': 'ptwiki', 'title': 'Síndrome de Kawasaki', 'badges': []},
#   'rowiki': {'site': 'rowiki', 'title': 'Boala Kawasaki', 'badges': []},
#   'ruwiki': {'site': 'ruwiki', 'title': 'Синдром Кавасаки', 'badges': []},
#   'simplewiki': {'site': 'simplewiki',
#    'title': 'Kawasaki disease',
#    'badges': []},
#   'siwiki': {'site': 'siwiki', 'title': 'කවසකි රෝගය', 'badges': []},
#   'slwiki': {'site': 'slwiki', 'title': 'Kawasakijev sindrom', 'badges': []},
#   'srwiki': {'site': 'srwiki', 'title': 'Kavasakijeva bolest', 'badges': []},
#   'svwiki': {'site': 'svwiki', 'title': 'Kawasakis sjukdom', 'badges': []},
#   'tawiki': {'site': 'tawiki', 'title': 'கவசாகி நோய்', 'badges': []},
#   'tewiki': {'site': 'tewiki', 'title': 'కవసాకి వ్యాధి', 'badges': []},
#   'thwiki': {'site': 'thwiki', 'title': 'โรคคาวาซากิ', 'badges': []},
#   'trwiki': {'site': 'trwiki', 'title': 'Kawasaki hastalığı', 'badges': []},
#   'ukwiki': {'site': 'ukwiki', 'title': 'Синдром Кавасакі', 'badges': []},
#   'viwiki': {'site': 'viwiki', 'title': 'Bệnh Kawasaki', 'badges': []},
#   'zhwiki': {'site': 'zhwiki', 'title': '川崎氏病', 'badges': []}}}

# %% [markdown]
# I am not totally sure what all of this means

# %% [markdown]
# I also have this code?

# %%
def _chunk_list(lst, n):
    """
    Yields successive n-sized chunks from lst.
    """
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def fetch_labels_for_qids(qids: list[str], lang='en'):
    """
    Fetches labels for a list of Wikidata QIDs or Property IDs.
    Handles API limits by chunking the requests.

    Args:
        qids (list[str]): A list of Wikidata Item IDs or Property IDs (e.g., ['Q515', 'P31']).
        lang (str): The language code for the labels (default is 'en').

    Returns:
        dict: A dictionary mapping QID to its label, or an error dictionary.
    """
    if not qids:
        return {}

    # Wikidata API limit for 'ids' parameter is typically 50
    MAX_IDS_PER_REQUEST = 50
    all_labels_map = {}

    # Chunk the QID list to respect the API limit
    for qid_chunk in _chunk_list(qids, MAX_IDS_PER_REQUEST):
        params = {
            'action': 'wbgetentities',
            'ids': '|'.join(qid_chunk), # Join QIDs with '|' for multiple requests
            'format': 'json',
            'props': 'labels',
            'languages': lang,
        }

        headers = {
            'User-Agent': 'Colab-Wikidata-Example/1.0 (https://colab.research.google.com; colab-user@example.com)'
        }

        try:
            response = requests.get(WIKIDATA_API_ENDPOINT, params=params, headers=headers, timeout=10)
            response.raise_for_status() # Raises an HTTPError for bad responses (4xx or 5xx)

            data = response.json()

            if 'error' in data:
                # If an error occurs in one chunk, return it immediately or log and continue
                return {"error": f"API Error fetching labels for chunk {qid_chunk}: {data['error']['info']}"}

            for qid_key, entity_info in data.get('entities', {}).items():
                label = entity_info.get('labels', {}).get(lang, {}).get('value')
                if label:
                    all_labels_map[qid_key] = label

        except requests.exceptions.RequestException as e:
            return {"error": f"Network or API request error for chunk {qid_chunk}: {e}"}
        except json.JSONDecodeError:
            return {"error": "Failed to decode JSON response for a label chunk."}

    return all_labels_map

# %%
def extract_labeled_claim_values(claims: dict, property_labels: dict) -> dict:
    """
    Extracts the main value for each claim, resolves QID values to labels,
    and returns a dictionary of 'property_label': 'value' pairs.

    Args:
        claims (dict): The 'claims' section of a Wikidata entity's data.
        property_labels (dict): A dictionary mapping Property IDs (P-numbers) to their labels.

    Returns:
        dict: A dictionary where keys are property labels and values are their extracted/resolved values.
    """
    labeled_values = {}
    qids_to_resolve = set() # Collect all QIDs that need labels

    # First pass: Extract raw values and collect QIDs
    extracted_raw_values = {}
    for prop_id, statements in claims.items():
        prop_label = property_labels.get(prop_id, prop_id) # Use ID if label not found
        
        # We often care about the primary value of the first statement for simplicity
        if statements:
            main_snak = statements[0].get('mainsnak')
            if not main_snak or 'datavalue' not in main_snak: # Skip if no main value
                continue

            data_value = main_snak['datavalue']
            value_type = data_value.get('type')

            if value_type == 'wikibase-entityid':
                qid_value = data_value['value']['id']
                extracted_raw_values[prop_label] = qid_value # Store QID for later resolution
                qids_to_resolve.add(qid_value)
            elif value_type == 'string' or value_type == 'external-id':
                extracted_raw_values[prop_label] = data_value['value']
            elif value_type == 'quantity':
                # Format quantity with unit if available
                amount = data_value['value']['amount']
                unit = data_value['value'].get('unit', '').replace('http://www.wikidata.org/entity/', '')
                if unit and unit != '1': # '1' is the URI for dimensionless unit
                    # Attempt to add unit to QID list for resolution
                    if unit.startswith('Q'):
                        qids_to_resolve.add(unit)
                        extracted_raw_values[prop_label] = (amount, unit) # Store as tuple for later unit resolution
                    else:
                        extracted_raw_values[prop_label] = f"{amount} {unit}" # Simple string for non-QID units
                else:
                    extracted_raw_values[prop_label] = amount
            elif value_type == 'time':
                # Simple representation for time
                extracted_raw_values[prop_label] = data_value['value']['time']
            elif value_type == 'globecoordinate':
                latitude = data_value['value']['latitude']
                longitude = data_value['value']['longitude']
                extracted_raw_values[prop_label] = f"Lat: {latitude}, Lon: {longitude}"
            elif value_type == 'monolingualtext':
                extracted_raw_values[prop_label] = data_value['value']['text']
            # Add more types as needed
            else:
                # For unhandled types or complex structures, just show the raw datavalue
                extracted_raw_values[prop_label] = f"[Unhandled Type: {value_type}]"

    # Second pass: Resolve QID values and units to labels
    if qids_to_resolve:
        resolved_value_labels = fetch_labels_for_qids(list(qids_to_resolve))
        if "error" in resolved_value_labels:
            print(f"Warning: Could not resolve some value labels: {resolved_value_labels['error']}")
            # Proceed with raw QIDs if resolution fails
            pass

        for prop_label, value in extracted_raw_values.items():
            if isinstance(value, str) and value.startswith('Q'):
                labeled_values[prop_label] = resolved_value_labels.get(value, value) # Use raw QID if label not found
            elif isinstance(value, tuple) and len(value) == 2 and value[1].startswith('Q'): # Handle quantity with QID unit
                amount, unit_qid = value
                unit_label = resolved_value_labels.get(unit_qid, unit_qid)
                labeled_values[prop_label] = f"{amount} {unit_label}"
            else:
                labeled_values[prop_label] = value
    else:
        labeled_values = extracted_raw_values # No QIDs to resolve

    return labeled_values

# %%
def test_one(QID):
    """
    Demonstrates fetching the complete JSON data for a given QID string
    and then resolving labels for properties and their values.
    """
    # The entity for the Durres city
    qid_example = QID
    print(f"--- Fetching ALL structured data for {qid_example} \n")

    entity_data = fetch_complete_entity_data(qid_example)

    if "error" in entity_data:
        print(f"Error: {entity_data['error']}")
        return

    # Display main entity's label and description
    print(f"--- Main Entity Details ({qid_example}) ---")
    entity_label = entity_data.get('labels', {}).get('en', {}).get('value', 'No label found')
    entity_description = entity_data.get('descriptions', {}).get('en', {}).get('value', 'No description found')
    print(f"Label: {entity_label}")
    print(f"Description: {entity_description}\n")

    print("--- Full Raw JSON Structure (Truncated for readability) ---")

    # We will print the Claims section specifically to show the attribute:value pairs
    claims = entity_data.get('claims', {}) # This is the full claims dict
    print(f"\nTotal Properties (Claims) Found: {len(claims)}\n")

    # Get labels for the property IDs themselves
    property_ids = list(claims.keys())
    property_labels = fetch_labels_for_qids(property_ids)
    if "error" in property_labels:
        #print(f"Error fetching property labels: {property_labels['error']}")
        property_labels = {pid: pid for pid in property_ids} # Fallback to IDs if labels fail
    else:
        #print("Property IDs found for this entity:")
        # Print property IDs with their labels
        labeled_properties_overview = {pid: property_labels.get(pid, 'Label Not Found') for pid in property_ids}
        #print(json.dumps(labeled_properties_overview, indent=2))

    # Now, extract and label the claim values
    print("\n--- Extracted Labeled Claim Values ---")
    labeled_claim_values = extract_labeled_claim_values(claims, property_labels)
    print(json.dumps(labeled_claim_values, indent=2, ensure_ascii=False))

    print("\n--- Details for 'P31' (instance of) ---")

    if 'P31' in claims:
        # P31 is 'instance of', and it will contain an array of statements
        p31_statements = claims['P31']

        # Iterate over the values found for P31
        extracted_value_qids = []
        for statement in p31_statements:
            # The value is usually nested deep in the datavalue section
            main_snak = statement['mainsnak']
            if main_snak['datavalue']['type'] == 'wikibase-entityid':
                value_qid = main_snak['datavalue']['value']['id']
                extracted_value_qids.append(value_qid)

        # Get the label for the P31 property itself
        p31_label = property_labels.get('P31', 'Label Not Found for P31')
        print(f"Property P31 label: '{p31_label}'")

        # Get the labels for the extracted QID values
        value_labels = fetch_labels_for_qids(extracted_value_qids)

        if "error" in value_labels:
            print(f"Error fetching value labels: {value_labels['error']}")
        else:
            print(f"Raw QID values for 'instance of' (P31): {extracted_value_qids}")
            labeled_values = [value_labels.get(qid, 'Label Not Found') for qid in extracted_value_qids]
            print(f"Labeled values for 'instance of' (P31): {labeled_values}")
    else:
        print("P31 property not found in claims.")

    print("\n------------------------------------------------------------")
    print("This raw data contains every single piece of structured information available for the entity.")

# %%
def process_qids_to_jsonl(qid_list, output_filename="entity_data.jsonl"):
    """
    Processes a list of QIDs, fetches structured data, labels it, and stores
    the results (or errors) into a JSONL file.
    
    Args:
        qid_list (list): A list of QID strings (e.g., ['Q534', 'Q142', 'Q999']).
        output_filename (str): The name of the JSONL file to write results to.
    """
    print(f"Starting processing for {len(qid_list)} QIDs.")
    print(f"Results will be written to '{output_filename}'.")
    
    successful_count = 0
    failed_count = 0

    with open(output_filename, 'w', encoding='utf-8') as f:
        for qid in qid_list:
            print(f"Processing {qid}...")
            
            # Initialize the base record structure
            record = {"QID": qid, "status": "failed", "error_message": None}
            
            try:
                # 1. Fetch raw entity data (using your existing function)
                entity_data = fetch_complete_entity_data(qid)

                if "error" in entity_data:
                    # Handle API/Not Found error directly
                    record["error_message"] = entity_data['error']
                    failed_count += 1
                else:
                    # 2. Extract basic details
                    entity_label = entity_data.get('labels', {}).get('en', {}).get('value', 'No label found')
                    entity_description = entity_data.get('descriptions', {}).get('en', {}).get('value', 'No description found')
                    claims = entity_data.get('claims', {})
                    
                    # 3. Get labels for the properties themselves (using your existing function)
                    property_ids = list(claims.keys())
                    property_labels = fetch_labels_for_qids(property_ids)

                    if "error" in property_labels:
                        # Fallback for label fetching error
                        property_labels = {pid: pid for pid in property_ids} 
                        print(f"  Warning: Failed to fetch property labels for {qid}. Using IDs.")
                    
                    # 4. Extract and label all claim values (using your existing function)
                    labeled_claim_values = extract_labeled_claim_values(claims, property_labels)

                    # 5. Structure the final dictionary for successful outcome
                    record.update({
                        "status": "success",
                        "label": entity_label,
                        "description": entity_description,
                        "attributes": labeled_claim_values
                    })
                    record.pop("error_message") # Remove error key on success
                    successful_count += 1
            
            except Exception as e:
                # Catch any unexpected execution errors
                record["error_message"] = f"Unexpected execution error: {type(e).__name__} - {e}"
                failed_count += 1

            # 6. Write the final record (whether success or failure) to the JSONL file
            json_line = json.dumps(record, ensure_ascii=False)
            f.write(json_line + '\n')
    
    print("\n--- Processing Complete ---")
    print(f"Total Processed: {len(qid_list)}")
    print(f"Successful Records: {successful_count}")
    print(f"Failed Records: {failed_count}")
    print("---------------------------\n")

# %%
test_one("Q265936")
# Out:
# --- Fetching ALL structured data for Q265936
#
# --- Main Entity Details (Q265936) ---
# Label: Kawasaki disease
# Description: human disease in which blood vessels throughout the body become inflamed
#
# --- Full Raw JSON Structure (Truncated for readability) ---
#
# Total Properties (Claims) Found: 53
#
#
# --- Extracted Labeled Claim Values ---
# {
#   "Commons category": "Kawasaki disease",
#   "OMIM ID": "611775",
#   "MedlinePlus ID": "000989",
#   "DiseasesDB": "7121",
#   "eMedicine ID": "965367",
#   "NDL Authority ID": "00565244",
#   "Freebase ID": "/m/040k6g",
#   "image": "Kawasaki Disease.png",
#   "Gran Enciclopèdia Catalana ID (former scheme)": "0262801",
#   "Patientplus ID": "kawasaki-disease-pro",
#   "Disease Ontology ID": "DOID:13378",
#   "NCI Thesaurus ID": "C34825",
#   "subclass of": "lymphadenitis",
#   "health specialty": "immunology",
#   "genetic association": "PPM1L",
#   "exact match": "http://purl.obolibrary.org/obo/DOID_13378",
#   "UMLS CUI": "C2936917",
#   "symptoms and signs": "strawberry tongue",
#   "Quora topic ID": "Kawasaki-Disease",
#   "JSTOR topic ID (archived)": "mucocutaneous-lymph-node-syndrome",
#   "WikiSkripta article ID": "4922",
#   "ICD-10-CM": "M30.3",
#   "GARD rare disease ID": "6816",
#   "Encyclopædia Universalis ID": "syndrome-de-kawasaki",
#   "Orphanet ID": "2331",
#   "MeSH descriptor ID": "D009080",
#   "ICD-9-CM": "446.1",
#   "MeSH tree code": "C14.907.940.560",
#   "drug or therapy used for treatment": "infliximab",
#   "Library of Congress authority ID": "sh87004913",
#   "named after": "Tomisaku Kawasaki",
#   "Genetics Home Reference Conditions ID": "kawasaki-disease",
#   "NHS Health A to Z ID": "kawasaki-disease",
#   "discoverer or inventor": "Tomisaku Kawasaki",
#   "KBpedia ID": "KawasakiDisease",
#   "on focus list of Wikimedia project": "WikiProject Medicine",
#   "KEGG ID": "H01718",
#   "ICD-11 ID (Foundation)": "540285662",
#   "ICD-11 ID (MMS)": "4A44.5",
#   "pronunciation audio": "LL-Q33810 (ori)-Psubhashish-କାୱାସାକି ଡିଜିଜ.wav",
#   "National Library of Israel J9U ID": "987007543956505171",
#   "OpenAlex ID": "C2910812759",
#   "YSO ID": "9205",
#   "instance of": "class of disease",
#   "WikiProjectMed ID": "Kawasaki disease",
#   "PatientsLikeMe condition ID": "kawasaki-disease",
#   "Experimental Factor Ontology ID": "0004246",
#   "UK Parliament thesaurus ID": "452750",
#   "UniProt disease ID": "DI-02892",
#   "Mondo ID": "MONDO_0012727",
#   "WikiKids ID": "Ziekte_van_Kawasaki",
#   "Gran Enciclopèdia Catalana ID": "malaltia-de-kawasaki",
#   "‎Yale LUX ID": "concept/75bcd2f7-c394-412f-9a91-aa0855d38960"
# }
#
# --- Details for 'P31' (instance of) ---
# Property P31 label: 'instance of'
# Raw QID values for 'instance of' (P31): ['Q112193867']
# Labeled values for 'instance of' (P31): ['class of disease']
#
# ------------------------------------------------------------
# This raw data contains every single piece of structured information available for the entity.

# %% [markdown]
# Now I will do this for the first 20 qids in my dataframe

# %%
top20 = qid_df.head(20)

# %%
top20 = top20['qid'].tolist()

# %%
top20
# Out:
# ['Q265936',
#  'Q49607',
#  'Q1195727',
#  'Q1582005',
#  'Q460186',
#  'Q486306',
#  'Q869018',
#  'Q857634',
#  'Q709133',
#  'Q675937',
#  'Q962932',
#  'Q18432',
#  'Q3311525',
#  'Q2181925',
#  'Q122248',
#  'Q192814',
#  'Q254038',
#  'Q4357239',
#  'Q30113',
#  'Q381941']

# %%
import time

# %%
start_time = time.perf_counter()

if __name__ == "__main__":
    #test_one("Q83285") # Article about Durres
    #test_one("Q7186")  # Article about Marie Kurie

    # I'm putting the list here, but you'll have a file with a list of QIDs here.
    qid_list_to_process = top20
    
    output_file = "entity_results.jsonl"

    # Run the main function
    process_qids_to_jsonl(qid_list_to_process, output_file)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(f"Code execution time: {elapsed_time:.4f} seconds")
# Out:
# Starting processing for 20 QIDs.
# Results will be written to 'entity_results.jsonl'.
# Processing Q265936...
# Processing Q49607...
# Processing Q1195727...
# Processing Q1582005...
# Processing Q460186...
# Processing Q486306...
# Processing Q869018...
# Processing Q857634...
# Processing Q709133...
# Processing Q675937...
# Processing Q962932...
# Processing Q18432...
# Processing Q3311525...
# Processing Q2181925...
# Processing Q122248...
# Processing Q192814...
# Processing Q254038...
# Processing Q4357239...
# Processing Q30113...
# Processing Q381941...
#
# --- Processing Complete ---
# Total Processed: 20
# Successful Records: 20
# Failed Records: 0
# ---------------------------
#
# Code execution time: 40.2595 seconds

# %% [markdown]
# It is going to take me 130 days to get all the wikidata for all my articles, so I am going to change my csv file to only have the top 1,000 articles for each country for the month

# %% [markdown]
# First, I am going to see how many artiles I actually have when I aggregate the pageviews for articles over the month

# %%
articles_df = pd.read_csv('final-project-data.csv')

# %%
articles_df.head()
# Out:
#          date country_code                         article       qid  \
# 0  2023-03-01           US                Kawasaki_disease   Q265936
# 1  2023-03-01           US  The_Elder_Scrolls_IV:_Oblivion    Q49607
# 2  2023-03-01           US             Marathon_Man_(film)  Q1195727
# 3  2023-03-01           US               Eleanor_Tomlinson  Q1582005
# 4  2023-03-01           US                      Alice_Neel   Q460186
#
#    pageviews lang_code
# 0        684        en
# 1        530        en
# 2        523        en
# 3        697        en
# 4       1044        en

# %%
articles = articles_df.groupby('article')['pageviews'].sum().reset_index()

# %%
articles.head()
# Out:
#                                              article  pageviews
# 0           !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT       3428
# 1  "C"_Is_for_(Please_Insert_Sophomoric_Genitalia...       1006
# 2                             "Christmas_tree"_files        371
# 3  "Crimea_is_a_'red_line'_for_Putin":_Dr._Jeremy...       1105
# 4                                "Freeway"_Rick_Ross      32293

# %% [markdown]
# I forgot that I need to make sure the country is the same

# %%
articles = articles_df.groupby(['article', "country_code"])['pageviews'].sum().reset_index()

# %%
articles.head()
# Out:
#                                              article country_code  pageviews
# 0           !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT           DE         99
# 1           !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT           GB        412
# 2           !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT           US       2917
# 3  "C"_Is_for_(Please_Insert_Sophomoric_Genitalia...           IN       1006
# 4                             "Christmas_tree"_files           GB        371

# %% [markdown]
# Let me also convert the unicode characters right now too

# %%
len(articles)
# Out:
# 488066

# %% [markdown]
# Okay, I am going to cut down the number of articles from the country specific dataframes

# %% [markdown]
# I'm just going to remake my country specific dataframes because I don't want to rerun all my code

# %%
USdf
JPdf
UKdf
INdf
DEdf

# %% [markdown]
# I need to sort by pageviews then just keep the top 10,000 or so

# %%
USdf = articles_df[(articles_df['country_code'] == 'US')]
JPdf = articles_df[(articles_df['country_code'] == 'JP')]
UKdf = articles_df[(articles_df['country_code'] == 'GB')]
INdf = articles_df[(articles_df['country_code'] == 'IN')]
DEdf = articles_df[(articles_df['country_code'] == 'DE')]

# %%
USdf.head()
# Out:
#          date country_code                         article       qid  \
# 0  2023-03-01           US                Kawasaki_disease   Q265936
# 1  2023-03-01           US  The_Elder_Scrolls_IV:_Oblivion    Q49607
# 2  2023-03-01           US             Marathon_Man_(film)  Q1195727
# 3  2023-03-01           US               Eleanor_Tomlinson  Q1582005
# 4  2023-03-01           US                      Alice_Neel   Q460186
#
#    pageviews lang_code
# 0        684        en
# 1        530        en
# 2        523        en
# 3        697        en
# 4       1044        en

# %%
USdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
JPdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
UKdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
INdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
DEdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
# Out:
#                                                  article country_code  \
# 0               !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT           DE
# 1                                "Hello,_World!"_program           DE
# 2      "No_Way_to_Prevent_This",_Says_Only_Nation_Whe...           DE
# 3                                    "Weird_Al"_Yankovic           DE
# 4                                                      $           DE
# ...                                                  ...          ...
# 85679                                          é½ææ           DE
# 85680                                             é½å¿           DE
# 85681                               êµ­ì _ì¬ì±ì_ë            DE
# 85682                             ìí¤ë¯¸ëì´_íêµ­           DE
# 85683                          ì¹´ë¥¼ë ì¤_í¸ì§ë°ëª¬           DE
#
#        pageviews
# 0             99
# 1            417
# 2           2748
# 3           1149
# 4           1397
# ...          ...
# 85679        141
# 85680        100
# 85681        135
# 85682         95
# 85683       3389
#
# [85684 rows x 3 columns]

# %%
USdf['article'] = USdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
JPdf['article'] = JPdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
UKdf['article'] = UKdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
INdf['article'] = INdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
DEdf['article'] = DEdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# Out:
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/3547201028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USdf['article'] = USdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/3547201028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JPdf['article'] = JPdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/3547201028.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UKdf['article'] = UKdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/3547201028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   INdf['article'] = INdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/3547201028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEdf['article'] = DEdf['article'].astype(str).str.encode('utf-8').str.decode('utf-8')

# %%
USdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
JPdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
UKdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
INdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
DEdf.groupby(['article', "country_code"])['pageviews'].sum().reset_index()
# Out:
#                                                  article country_code  \
# 0               !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT           DE
# 1                                "Hello,_World!"_program           DE
# 2      "No_Way_to_Prevent_This",_Says_Only_Nation_Whe...           DE
# 3                                    "Weird_Al"_Yankovic           DE
# 4                                                      $           DE
# ...                                                  ...          ...
# 85680                                          é½ææ           DE
# 85681                                             é½å¿           DE
# 85682                               êµ­ì _ì¬ì±ì_ë            DE
# 85683                             ìí¤ë¯¸ëì´_íêµ­           DE
# 85684                          ì¹´ë¥¼ë ì¤_í¸ì§ë°ëª¬           DE
#
#        pageviews
# 0             99
# 1            417
# 2           2748
# 3           1149
# 4           1397
# ...          ...
# 85680        141
# 85681        100
# 85682        135
# 85683         95
# 85684       3389
#
# [85685 rows x 3 columns]

# %%
DEdf
# Out:
#                date country_code                          article         qid  \
# 4754982  2023-03-01           DE                Carles_Puigdemont    Q4740163
# 4754983  2023-03-01           DE               Liste_von_Pistolen      Q60526
# 4754984  2023-03-01           DE            Priyanka_Chopra_Jonas     Q158957
# 4754985  2023-03-01           DE  Denis_Wladimirowitsch_Puschilin   Q16514790
# 4754986  2023-03-01           DE                         Dominica        Q784
# ...             ...          ...                              ...         ...
# 5636456  2023-03-31           DE            The_Glory_(TV_series)  Q113197148
# 5636457  2023-03-31           DE                 Evan_Gershkovich  Q117337455
# 5636458  2023-03-31           DE          Ù
# Ø±ÛÙÛÙ_Ù
# ÙÙØ±Ù       Q4616
# 5636459  2023-03-31           DE            ÙØ¯ÛÙ_Ø¨Ø§Ø²ÙÙØ¯  Q106396209
# 5636460  2023-03-31           DE                  Fabio_Cannavaro     Q102027
#
#          pageviews lang_code
# 4754982        101        br
# 4754983        149        de
# 4754984        215        de
# 4754985        109        de
# 4754986        211        de
# ...            ...       ...
# 5636456        211        en
# 5636457       1032        en
# 5636458        121        fa
# 5636459         93        fa
# 5636460        142        it
#
# [881479 rows x 6 columns]

# %% [markdown]
# I am still getting some weird titles

# %%
len(USdf)
# Out:
# 3000

# %%
USdf.sort_values(by='pageviews', ascending=False, inplace=True)
JPdf.sort_values(by='pageviews', ascending=False, inplace=True)
UKdf.sort_values(by='pageviews', ascending=False, inplace=True)
INdf.sort_values(by='pageviews', ascending=False, inplace=True)
DEdf.sort_values(by='pageviews', ascending=False, inplace=True)
# Out:
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/328324033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   USdf.sort_values(by='pageviews', ascending=False, inplace=True)
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/328324033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JPdf.sort_values(by='pageviews', ascending=False, inplace=True)
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/328324033.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UKdf.sort_values(by='pageviews', ascending=False, inplace=True)
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/328324033.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   INdf.sort_values(by='pageviews', ascending=False, inplace=True)
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/328324033.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEdf.sort_values(by='pageviews', ascending=False, inplace=True)

# %%
len(USdf)
# Out:
# 3000

# %% [markdown]
# Wait, I need to consolidate these first

# %%
USdf = USdf.head(3000)
JPdf = JPdf.head(3000)
UKdf = UKdf.head(3000)
INdf = INdf.head(3000)
DEdf = DEdf.head(3000)

# %% [markdown]
# I am going to do the top 3000 articles for each month

# %%
csv_data2 = pd.concat([USdf, JPdf, UKdf, INdf, DEdf], ignore_index=True)

# %%
csv_data2.head()
# Out:
#          date country_code                article      qid  pageviews  \
# 0  2023-03-15           US              Main_Page    Q5296    7132908
# 1  2023-03-16           US              Main_Page    Q5296    4532076
# 2  2023-03-01           US  Cookie_(informatique)  Q178995    4251750
# 3  2023-03-17           US              Main_Page    Q5296    4233371
# 4  2023-03-10           US  Cookie_(informatique)  Q178995    4158637
#
#   lang_code
# 0        en
# 1        en
# 2        fr
# 3        en
# 4        fr

# %%
len(csv_data2)
# Out:
# 15000

# %%
csv_data2.to_csv("final-project-data2.csv", index=False)

# %%
articles = articles_df.groupby(['article', "country_code"])['pageviews'].sum().reset_index()

# %%
USdf_new = USdf.drop('date', axis=1) 
JPdf_new = JPdf.drop('date', axis=1) 
UKdf_new = UKdf.drop('date', axis=1) 
INdf_new = INdf.drop('date', axis=1) 
DEdf_new = DEdf.drop('date', axis=1)

# %%
USdf.groupby(['article', 'country_code', 'qid'])['pageviews'].sum().reset_index(name='total_pageviews')
JPdf.groupby(['article', 'country_code', 'qid'])['pageviews'].sum().reset_index(name='total_pageviews')
UKdf.groupby(['article', 'country_code', 'qid'])['pageviews'].sum().reset_index(name='total_pageviews')
INdf.groupby(['article', 'country_code', 'qid'])['pageviews'].sum().reset_index(name='total_pageviews')
DEdf.groupby(['article', 'country_code', 'qid'])['pageviews'].sum().reset_index(name='total_pageviews')
# Out:
#                              article country_code         qid  total_pageviews
# 0              (469705)_ÇKÃ¡Ì¦gÃ¡ra           DE   Q15035845             7186
# 1                           1._MÃ¤rz           DE       Q2393            14034
# 2                          10._MÃ¤rz           DE       Q2397            11293
# 3                          11._MÃ¤rz           DE       Q2398             6103
# 4                          12._MÃ¤rz           DE       Q2402             6542
# ...                              ...          ...         ...              ...
# 1401         Ø¨Ø±Ø§Ø¯Ø±Ø§Ù_ÙÛÙØ§           DE  Q108901009             4806
# 1402          Ø±ÙØ²_Ø¬ÙØ§ÙÛ_Ø²Ù           DE      Q38964             9790
# 1403                 ÙÙØªâØ³ÛÙ           DE    Q1568159             5631
# 1404              ã¡ã¤ã³ãã¼ã¸           DE       Q5296            62573
# 1405  å¡æä»å°¼ç§å¤«èªåæ­¥æ§           DE      Q37116            80545
#
# [1406 rows x 4 columns]

# %%
USdf.sort_values(by='pageviews', ascending=False, inplace=True)
JPdf.sort_values(by='pageviews', ascending=False, inplace=True)
UKdf.sort_values(by='pageviews', ascending=False, inplace=True)
INdf.sort_values(by='pageviews', ascending=False, inplace=True)
DEdf.sort_values(by='pageviews', ascending=False, inplace=True)
# Out:
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/328324033.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DEdf.sort_values(by='pageviews', ascending=False, inplace=True)

# %%
csv_data3 = pd.concat([USdf, JPdf, UKdf, INdf, DEdf], ignore_index=True)

# %%
len(csv_data3)
# Out:
# 15000

# %%
csv_data3.to_csv("final-project-qids.csv", index=False)

# %%
qid_df2 = qid_df2[["article", "qid"]]

# %%
if __name__ == "__main__":
    #test_one("Q83285") # Article about Durres
    #test_one("Q7186")  # Article about Marie Kurie

    # I'm putting the list here, but you'll have a file with a list of QIDs here.
    qid_list_to_process = qid_df2
    
    output_file = "entity_results.jsonl2"

    # Run the main function
    process_qids_to_jsonl(qid_list_to_process, output_file)
# Out:
# Starting processing for 15000 QIDs.
# Results will be written to 'entity_results.jsonl2'.
# Processing article...
# Processing qid...
#
# --- Processing Complete ---
# Total Processed: 15000
# Successful Records: 0
# Failed Records: 2
# ---------------------------

# %% [markdown]
# This got too messy and I am not confused, so I am going to do this again *in a more streamlined fashion and hopefully get what I want

# %% [markdown]
# 1. split my final-project-data.csv into it's respective languages

# %%
newdf = pd.read_csv('final-project-data.csv')

# %%
US = newdf[newdf['country_code'].str.contains("US", case=False, na=False)]

# %%
len(US)
# Out:
# 1252328

# %%
JP = newdf[newdf['country_code'].str.contains("JP", case=False, na=False)]
UK = newdf[newdf['country_code'].str.contains("UK", case=False, na=False)]
IN = newdf[newdf['country_code'].str.contains("IN", case=False, na=False)]
DE = newdf[newdf['country_code'].str.contains("DE", case=False, na=False)]

# %%
len(UK)
# Out:
# 0

# %%
US['article'] = US['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
JP['article'] = JP['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
UK['article'] = UK['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
IN['article'] = IN['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
DE['article'] = DE['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# Out:
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/2130759313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   US['article'] = US['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/2130759313.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JP['article'] = JP['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/2130759313.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IN['article'] = IN['article'].astype(str).str.encode('utf-8').str.decode('utf-8')
# /var/folders/5q/q02qx9t97hdgr20tw_hpw2zw0000gn/T/ipykernel_18017/2130759313.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DE['article'] = DE['article'].astype(str).str.encode('utf-8').str.decode('utf-8')

# %%
US.shape, JP.shape
# Out:
# ((5000, 4), (5000, 4))

# %%
US
# Out:
#                date country_code                         article       qid  \
# 0        2023-03-01           US                Kawasaki_disease   Q265936
# 1        2023-03-01           US  The_Elder_Scrolls_IV:_Oblivion    Q49607
# 2        2023-03-01           US             Marathon_Man_(film)  Q1195727
# 3        2023-03-01           US               Eleanor_Tomlinson  Q1582005
# 4        2023-03-01           US                      Alice_Neel   Q460186
# ...             ...          ...                             ...       ...
# 1252323  2023-03-31           US                    Jerry_Nadler   Q505598
# 1252324  2023-03-31           US             68â95â99.7_rule   Q847822
# 1252325  2023-03-31           US                          France      Q142
# 1252326  2023-03-31           US                         YouTube      Q866
# 1252327  2023-03-31           US         æ­æ´å
# Â·ç¦å°æ©æ¯     Q4653
#
#          pageviews lang_code
# 0              684        en
# 1              530        en
# 2              523        en
# 3              697        en
# 4             1044        en
# ...            ...       ...
# 1252323        512        en
# 1252324        530        en
# 1252325        685        fr
# 1252326       3071        uk
# 1252327        557        zh
#
# [1252328 rows x 6 columns]

# %%
len(US)
# Out:
# 1252328

# %%
US = US.groupby(['article', 'qid', 'country_code'])['pageviews'].sum().reset_index(name='total_pageviews')

# %%
len(US)
# Out:
# 105113

# %%
US.head()
# Out:
#                                              article         qid country_code  \
# 0           !aaaH-aH_,yawA_eM_ekaT_oT_gnimoC_er'yehT    Q3990384           US
# 1  "Crimea_is_a_'red_line'_for_Putin":_Dr._Jeremy...  Q117038809           US
# 2                                "Freeway"_Rick_Ross     Q606032           US
# 3                                "Hangman"_Adam_Page   Q16525240           US
# 4                            "Hello,_World!"_program     Q131303           US
#
#    total_pageviews
# 0             2917
# 1             1105
# 2            31601
# 3             4915
# 4            35450

# %%
JP.head()
# Out:
#                date country_code                         article         qid  \
# 1252328  2023-03-01           JP               Compartment_No._6  Q107092356
# 1252329  2023-03-01           JP                 çå®é«ç°æ´¾   Q10437214
# 1252330  2023-03-01           JP  ãã«ã¨ãã¹ãã¨å¬åç£     Q483263
# 1252331  2023-03-01           JP                          ä¼½è¶      Q28084
# 1252332  2023-03-01           JP               å½é72ç³»é»è»   Q11421672
#
#          pageviews lang_code
# 1252328        104        en
# 1252329        167        ja
# 1252330        285        ja
# 1252331        299        ja
# 1252332        181        ja

# %%
JP = JP.groupby(['article', 'qid', 'country_code'])['pageviews'].sum().reset_index(name='total_pageviews')
UK = UK.groupby(['article', 'qid', 'country_code'])['pageviews'].sum().reset_index(name='total_pageviews')
IN = IN.groupby(['article', 'qid', 'country_code'])['pageviews'].sum().reset_index(name='total_pageviews')
DE = DE.groupby(['article', 'qid', 'country_code'])['pageviews'].sum().reset_index(name='total_pageviews')

# %%
len(UK)
# Out:
# 0

# %%
US.sort_values(by='total_pageviews', ascending=False, inplace=True)
JP.sort_values(by='total_pageviews', ascending=False, inplace=True)
UK.sort_values(by='total_pageviews', ascending=False, inplace=True)
IN.sort_values(by='total_pageviews', ascending=False, inplace=True)
DE.sort_values(by='total_pageviews', ascending=False, inplace=True)

# %%
US.head()
# Out:
#                       article      qid country_code  total_pageviews
# 58626               Main_Page    Q5296           US         89005625
# 21448   Cookie_(informatique)  Q178995           US         49289112
# 45655            Jimmy_Carter   Q23685           US          4964868
# 101896     ã¡ã¤ã³ãã¼ã¸    Q5296           US          4061575
# 99998                 YouTube     Q866           US          3624806

# %%
len(US)
# Out:
# 105113

# %%
US = US.head(5000)
JP = JP.head(5000)
UK = UK.head(5000)
IN = IN.head(5000)
DE = DE.head(5000)

# %%
all_qids_df = pd.concat([US, JP, UK, IN, DE], ignore_index=True)

# %%
len(all_qids_df)
# Out:
# 20000

# %%
all_qids_df.to_csv("top5000_each.csv", index=False)

# %%
all_qids_df.head()
# Out:
#                  article      qid  total_pageviews
# 0              Main_Page    Q5296         89005625
# 1  Cookie_(informatique)  Q178995         49289112
# 2           Jimmy_Carter   Q23685          4964868
# 3     ã¡ã¤ã³ãã¼ã¸    Q5296          4061575
# 4                YouTube     Q866          3624806

# %%
all_qids = all_qids_df['qid'].unique().tolist()

# %%
len(all_qids)
# Out:
# 16108

# %%
if __name__ == "__main__":
    #test_one("Q83285") # Article about Durres
    #test_one("Q7186")  # Article about Marie Kurie

    # I'm putting the list here, but you'll have a file with a list of QIDs here.
    qid_list_to_process = all_qids[:5]
    
    output_file = "entity_results-test.jsonl"

    # Run the main function
    process_qids_to_jsonl(qid_list_to_process, output_file)
# Out:
# Starting processing for 5 QIDs.
# Results will be written to 'entity_results-test.jsonl'.
# Processing Q5296...
# Processing Q178995...
# Processing Q23685...
# Processing Q866...
# Processing Q42253...
#
# --- Processing Complete ---
# Total Processed: 5
# Successful Records: 5
# Failed Records: 0
# ---------------------------

# %%
if __name__ == "__main__":
    #test_one("Q83285") # Article about Durres
    #test_one("Q7186")  # Article about Marie Kurie

    # I'm putting the list here, but you'll have a file with a list of QIDs here.
    qid_list_to_process = all_qids
    
    output_file = "entity_results2.jsonl"

    # Run the main function
    process_qids_to_jsonl(qid_list_to_process, output_file)
# Out:
# Starting processing for 16108 QIDs.
# Results will be written to 'entity_results2.jsonl'.
# Processing Q5296...
# Processing Q178995...
# Processing Q23685...
# Processing Q866...
# Processing Q42253...
# Processing Q2429697...
# Processing Q747452...
# Processing Q322056...
# Processing Q115564437...
# Processing Q35127...
# Processing Q114929139...
# Processing Q14752155...
# Processing Q834730...
# Processing Q193555...
# Processing Q108673301...
# Processing Q181817...
# Processing Q106997...
# Processing Q80322358...
# Processing Q214289...
# Processing Q17460747...
# Processing Q83808444...
# Processing Q87131973...
# Processing Q105883400...
# Processing Q349852...
# Processing Q254947...
# Processing Q105840301...
# Processing Q56274719...
# Processing Q21738166...
# Processing Q95...
# Processing Q15908324...
# Processing Q110664384...
# Processing Q26457...
# Processing Q445017...
# Processing Q4109...
# Processing Q24891605...
# Processing Q31970512...
# Processing Q59656031...
# Processing Q112183099...
# Processing Q285450...
# Processing Q22686...
# Processing Q28682891...
# Processing Q6984524...
# Processing Q30...
# Processing Q1783949...
# Processing Q635...
# Processing Q1469999...
# Processing Q117314558...
# Processing Q2680...
# Processing Q43416...
# Processing Q165194...
# Processing Q6596115...
# Processing Q24890727...
# Processing Q996954...
# Processing Q61707579...
# Processing Q40026...
# Processing Q34460...
# Processing Q157191...
# Processing Q116788716...
# Processing Q84712809...
# Processing Q23...
# Processing Q2855440...
# Processing Q6418591...
# Processing Q104859271...
# Processing Q6159960...
# Processing Q775231...
# Processing Q73885...
# Processing Q56876444...
# Processing Q320670...
# Processing Q65063267...
# Processing Q146...
# Processing Q524281...
# Processing Q615...
# Processing Q34086...
